# %% [markdown]
# # 📋 Key Concepts of Machine Learning

# %%
import numpy as np
import statistics as st
import random
import matplotlib.pyplot as plt

# %%
X = np.random.random((200, 1))
X[:10]
# Out:
# array([[0.04699839],
#        [0.99790321],
#        [0.07834839],
#        [0.5041019 ],
#        [0.76063382],
#        [0.30850294],
#        [0.18579004],
#        [0.70006924],
#        [0.58029697],
#        [0.49353956]])

# %%
print(f"Mean of X: {np.mean(X)}\nStandard Deviation of X: {np.std(X)}")
# Out:
# Mean of X: 0.5055879416513097
# Standard Deviation of X: 0.2944593650613239

# %%
# Normalization

def Normalize(data):
    return (data - np.min(data)) / (np.max(data) - np.min(data))

XN = Normalize(X)
XN[:10]
# Out:
# array([[0.04520348],
#        [1.        ],
#        [0.07668178],
#        [0.50417775],
#        [0.76175956],
#        [0.30777828],
#        [0.18456315],
#        [0.70094711],
#        [0.58068465],
#        [0.49357218]])

# %%
print(f"Mean of XN: {np.mean(XN)}\nStandard Deviation of XN: {np.std(XN)}")
# Out:
# Mean of XN: 0.5056698710857994
# Standard Deviation of XN: 0.29566447856420996

# %%
# Standardization

def Standardize(data):
    return (data - np.mean(data)) / np.std(data)

XS = Standardize(X)
XS[:10]
# Out:
# array([[-1.55739503],
#        [ 1.67192938],
#        [-1.45092874],
#        [-0.00504668],
#        [ 0.86614967],
#        [-0.66931137],
#        [-1.08605105],
#        [ 0.66046906],
#        [ 0.2537159 ],
#        [-0.04091695]])

# %%
# Plotting (Data - Normalized)

fig, ax = plt.subplots(1, 3, figsize=(20, 5))

ax[0].plot(
    X,
    "^",
    color = "blue",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Randomly Generated Data",
);
ax[0].set_title("Randomly Generated Data", fontsize = 12);
ax[0].legend(loc = "upper right", fontsize = 8);

ax[1].plot(
    XN,
    "v",
    color = "red",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Normalized Data"
);
ax[1].set_title("Normalized Randomly Generated Data", fontsize = 12);
ax[1].legend(loc = "upper right", fontsize = 8);

ax[2].plot(
    X,
    "^",
    color = "blue",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Randomly Generated Data"
);
ax[2].plot(
    XN,
    "v",
    color = "red",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Standardized Data"
);

ax[2].set_title("Normalized & Randomly Generated Data Together", fontsize = 12);
ax[2].legend(loc = "upper right", fontsize = 8);

X_var = [X, XN]
for i in range(len(X_var)):
    ax[i].plot(
        np.std(X_var[i]),
        "o",
        alpha = 0.8,
        color = "red",
        markersize = 7,
        markeredgecolor = "black",
);

# %%
# Plotting (Data - Standardized)

fig, ax = plt.subplots(1, 3, figsize=(20, 5))

ax[0].plot(
    X,
    "^",
    color = "blue",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Randomly Generated Data"
);
ax[0].set_title("Randomly Generated Data", fontsize = 12);
ax[0].legend(loc = "upper right", fontsize = 8);

ax[1].plot(
    XS,
    "v",
    color = "green",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Standardized Data"
);
ax[1].set_title("Standardized Data", fontsize = 12);
ax[1].legend(loc = "upper right", fontsize = 8);

ax[2].plot(
    X,
    "^",
    color = "blue",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Randomly Generated Data"
);
ax[2].plot(
    XS,
    "v",
    color = "green",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Standardized Data"
);

ax[2].set_title("Standardized & Randomly Generated Data Together", fontsize = 12);
ax[2].legend(loc = "upper right", fontsize = 8);

X_var = [X, XS]
for i in range(len(X_var)):
    ax[i].plot(
        np.std(X_var[i]),
        "o",
        alpha = 0.8,
        color = "red",
        markersize = 7,
        markeredgecolor = "black",
);
