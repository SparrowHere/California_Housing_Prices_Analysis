# %% [markdown]
# # 📋 Key Concepts of Machine Learning

# %%
import numpy as np
import statistics as st
import random
import matplotlib.pyplot as plt

# %%
X = np.random.random((200, 1))
X[:10]
# Out:
# array([[0.34777784],
#        [0.69536434],
#        [0.05521571],
#        [0.7692153 ],
#        [0.13976945],
#        [0.13769174],
#        [0.72979932],
#        [0.72998988],
#        [0.69992555],
#        [0.45952911]])

# %%
print(f"Mean of X: {np.mean(X)}\nStandard Deviation of X: {np.std(X)}")
# Out:
# Mean of X: 0.4923424362462423
# Standard Deviation of X: 0.2836495591749437

# %%
# Normalization

def Normalize(data):
    return (data - np.min(data)) / (np.max(data) - np.min(data))

XN = Normalize(X)
XN[:10]
# Out:
# array([[0.33937676],
#        [0.69888757],
#        [0.03677797],
#        [0.77527206],
#        [0.12423242],
#        [0.12208343],
#        [0.73450388],
#        [0.73470098],
#        [0.70360526],
#        [0.45496176]])

# %%
print(f"Mean of XN: {np.mean(XN)}\nStandard Deviation of XN: {np.std(XN)}")
# Out:
# Mean of XN: 0.4889007889331451
# Standard Deviation of XN: 0.29338045294610937

# %%
# Standardization

def Standardize(data):
    return (data - np.mean(data)) / np.std(data)

XS = Standardize(X)
XS[:10]
# Out:
# array([[-0.50965915],
#        [ 0.71574907],
#        [-1.54108023],
#        [ 0.9761089 ],
#        [-1.24298795],
#        [-1.25031287],
#        [ 0.83714878],
#        [ 0.83782061],
#        [ 0.7318295 ],
#        [-0.11568264]])

# %%
# Plotting (Data - Normalized)

fig, ax = plt.subplots(1, 3, figsize=(20, 5))

ax[0].plot(
    X,
    "^",
    color = "blue",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Randomly Generated Data",
);
ax[0].set_title("Randomly Generated Data", fontsize = 12);
ax[0].legend(loc = "upper right", fontsize = 8);

ax[1].plot(
    XN,
    "v",
    color = "red",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Normalized Data"
);
ax[1].set_title("Normalized Randomly Generated Data", fontsize = 12);
ax[1].legend(loc = "upper right", fontsize = 8);

ax[2].plot(
    X,
    "^",
    color = "blue",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Randomly Generated Data"
);
ax[2].plot(
    XN,
    "v",
    color = "red",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Standardized Data"
);

ax[2].set_title("Normalized & Randomly Generated Data Together", fontsize = 12);
ax[2].legend(loc = "upper right", fontsize = 8);

X_var = [X, XN]
for i in range(len(X_var)):
    ax[i].plot(
        np.std(X_var[i]),
        "o",
        alpha = 0.8,
        color = "red",
        markersize = 7,
        markeredgecolor = "black",
);

# %%
# Plotting (Data - Standardized)

fig, ax = plt.subplots(1, 3, figsize=(20, 5))

ax[0].plot(
    X,
    "^",
    color = "blue",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Randomly Generated Data"
);
ax[0].set_title("Randomly Generated Data", fontsize = 12);
ax[0].legend(loc = "upper right", fontsize = 8);

ax[1].plot(
    XS,
    "v",
    color = "green",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Standardized Data"
);
ax[1].set_title("Standardized Data", fontsize = 12);
ax[1].legend(loc = "upper right", fontsize = 8);

ax[2].plot(
    X,
    "^",
    color = "blue",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Randomly Generated Data"
);
ax[2].plot(
    XS,
    "v",
    color = "green",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Standardized Data"
);

ax[2].set_title("Standardized & Randomly Generated Data Together", fontsize = 12);
ax[2].legend(loc = "upper right", fontsize = 8);

X_var = [X, XS]
for i in range(len(X_var)):
    ax[i].plot(
        np.std(X_var[i]),
        "o",
        alpha = 0.8,
        color = "red",
        markersize = 7,
        markeredgecolor = "black",
);
