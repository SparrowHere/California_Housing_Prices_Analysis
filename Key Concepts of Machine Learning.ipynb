# %% [markdown]
# # 📋 Key Concepts of Machine Learning

# %%
import numpy as np
import statistics as st
import random
import matplotlib.pyplot as plt

# %%
X = np.random.random((200, 1))
X[:10]
# Out:
# array([[0.63604662],
#        [0.20486029],
#        [0.97994177],
#        [0.2862948 ],
#        [0.29433921],
#        [0.90068994],
#        [0.13821194],
#        [0.03402847],
#        [0.02716519],
#        [0.91106034]])

# %%
print(f"Mean of X: {np.mean(X)}\nStandard Deviation of X: {np.std(X)}")
# Out:
# Mean of X: 0.5000047465112921
# Standard Deviation of X: 0.3010209944967566

# %%
# Normalization

def Normalize(data):
    return (data - np.min(data)) / (np.max(data) - np.min(data))

XN = Normalize(X)
XN[:10]
# Out:
# array([[0.63361352],
#        [0.19757725],
#        [0.98137676],
#        [0.27992773],
#        [0.28806262],
#        [0.90123352],
#        [0.13017925],
#        [0.02482394],
#        [0.01788345],
#        [0.91172056]])

# %%
print(f"Mean of XN: {np.mean(XN)}\nStandard Deviation of XN: {np.std(XN)}")
# Out:
# Mean of XN: 0.4960414602516491
# Standard Deviation of XN: 0.3044068450689373

# %%
# Standardization

def Standardize(data):
    return (data - np.mean(data)) / np.std(data)

XS = Standardize(X)
XS[:10]
# Out:
# array([[ 0.45193484],
#        [-0.98047797],
#        [ 1.59436394],
#        [-0.70995031],
#        [-0.68322657],
#        [ 1.3310872 ],
#        [-1.20188562],
#        [-1.54798596],
#        [-1.57078599],
#        [ 1.36553796]])

# %%
# Plotting (Data - Normalized)

fig, ax = plt.subplots(1, 3, figsize=(20, 5))

ax[0].plot(
    X,
    "^",
    color = "blue",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Randomly Generated Data",
);
ax[0].set_title("Randomly Generated Data", fontsize = 12);
ax[0].legend(loc = "upper right", fontsize = 8);

ax[1].plot(
    XN,
    "v",
    color = "red",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Normalized Data"
);
ax[1].set_title("Normalized Randomly Generated Data", fontsize = 12);
ax[1].legend(loc = "upper right", fontsize = 8);

ax[2].plot(
    X,
    "^",
    color = "blue",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Randomly Generated Data"
);
ax[2].plot(
    XN,
    "v",
    color = "red",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Standardized Data"
);

ax[2].set_title("Normalized & Randomly Generated Data Together", fontsize = 12);
ax[2].legend(loc = "upper right", fontsize = 8);

X_var = [X, XN]
for i in range(len(X_var)):
    ax[i].plot(
        np.std(X_var[i]),
        "o",
        alpha = 0.8,
        color = "red",
        markersize = 7,
        markeredgecolor = "black",
);

# %%
# Plotting (Data - Standardized)

fig, ax = plt.subplots(1, 3, figsize=(20, 5))

ax[0].plot(
    X,
    "^",
    color = "blue",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Randomly Generated Data"
);
ax[0].set_title("Randomly Generated Data", fontsize = 12);
ax[0].legend(loc = "upper right", fontsize = 8);

ax[1].plot(
    XS,
    "v",
    color = "green",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Standardized Data"
);
ax[1].set_title("Standardized Data", fontsize = 12);
ax[1].legend(loc = "upper right", fontsize = 8);

ax[2].plot(
    X,
    "^",
    color = "blue",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Randomly Generated Data"
);
ax[2].plot(
    XS,
    "v",
    color = "green",
    alpha = 0.5,
    markersize = 5,
    markeredgecolor = "black",
    label = "Standardized Data"
);

ax[2].set_title("Standardized & Randomly Generated Data Together", fontsize = 12);
ax[2].legend(loc = "upper right", fontsize = 8);

X_var = [X, XS]
for i in range(len(X_var)):
    ax[i].plot(
        np.std(X_var[i]),
        "o",
        alpha = 0.8,
        color = "red",
        markersize = 7,
        markeredgecolor = "black",
);

# %% [markdown]
# ### Scatter Matrix

# %%
import pandas as pd

df_random = pd.DataFrame(np.random.randn(1000, 4), columns=['A', 'B', 'C', 'D'])
df_random.head()
# Out:
#           A         B         C         D
# 0  2.400418  1.322516 -0.557453  1.051014
# 1 -0.438281 -0.990646 -0.067290  0.180985
# 2  0.647312  0.789597  1.773802  0.719925
# 3 -0.352602  1.053899  2.186117 -1.773373
# 4 -0.797471 -0.894072  0.050562  1.279943

# %%
pd.plotting.scatter_matrix(
    frame = df_random,
    alpha = 0.5,
    figsize = (10, 10),
    grid = True,
    marker = "o",
    range_padding = 0.1,
);

# %% [markdown]
# ### Correlations

# %%
corr_random = df_random.corr(
    method = "spearman",
    min_periods = 1
)
corr_random.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_ef736_row0_col0, #T_ef736_row1_col1, #T_ef736_row2_col2, #T_ef736_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ef736_row0_col1, #T_ef736_row0_col3, #T_ef736_row1_col0, #T_ef736_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ef736_row0_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_ef736_row1_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_ef736_row2_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_ef736_row2_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_ef736_row2_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_ef736_row3_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_ef736_row3_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_ef736_row3_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ef736">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef736_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_ef736_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_ef736_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_ef736_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef736_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_ef736_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ef736_row0_col1" class="data row0 col1" >-0.074899</td>
#       <td id="T_ef736_row0_col2" class="data row0 col2" >0.016405</td>
#       <td id="T_ef736_row0_col3" class="data row0 col3" >-0.012502</td>
#     </tr>
#     <tr>
#       <th id="T_ef736_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_ef736_row1_col0" class="data row1 col0" >-0.074899</td>
#       <td id="T_ef736_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ef736_row1_col2" class="data row1 col2" >0.003973</td>
#       <td id="T_ef736_row1_col3" class="data row1 col3" >0.035514</td>
#     </tr>
#     <tr>
#       <th id="T_ef736_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_ef736_row2_col0" class="data row2 col0" >0.016405</td>
#       <td id="T_ef736_row2_col1" class="data row2 col1" >0.003973</td>
#       <td id="T_ef736_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_ef736_row2_col3" class="data row2 col3" >0.047958</td>
#     </tr>
#     <tr>
#       <th id="T_ef736_level0_row3" class="row_heading level0 row3" >D</th>
#       <td id="T_ef736_row3_col0" class="data row3 col0" >-0.012502</td>
#       <td id="T_ef736_row3_col1" class="data row3 col1" >0.035514</td>
#       <td id="T_ef736_row3_col2" class="data row3 col2" >0.047958</td>
#       <td id="T_ef736_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
